# %%
import numpy as np
import pandas as pd
import swifter

import yaml
import importlib
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from os import listdir
from collections import Counter, defaultdict

import get_emotes
importlib.reload(get_emotes)
import streaming_chat
importlib.reload(streaming_chat)
import constants

# %%
bttv = f'{constants.extensions_path}/ajopnjidmegmdimjlfnijceegpefgped/7.2.80_0'
ff = f'{constants.extensions_path}/fadndhdgpmmaapbmfcknlfgcflmmmieb/1.57_0'
ublock= f'{constants.extensions_path}/cjpalhdlnbpafiamejdnhcphjbkeiagm/1.27.10_0'

chrome_driver = constants.chrome_driver_path
chrome_options = Options()
chrome_options.add_argument(f'--load-extension={ff},{bttv},{ublock}')

driver = webdriver.Chrome(chrome_driver, options=chrome_options)

# %%
twitch_driver = get_emotes.TwitchSetup(driver)
twitch_driver.login("ScrapingIsFun", "AutoScraperDSE")
twitch_driver.adjust_settings()

# %%
with open("emotes.yaml", 'r') as stream:
    emotes = yaml.safe_load(stream)

# %%
emote_list = []
for channel in emotes.keys():
    for emote_type in emotes[channel].keys():
        for emote in emotes[channel][emote_type]:
            emote_list.append({'name': emote, 'emote_type': emote_type, 'channel': channel})

# %%
emote_df = pd.DataFrame(emote_list)

# %%
emote_channel_df = emote_df[['name', 'channel']].copy()

# %%
emote_df = emote_df.drop('channel', axis=1).drop_duplicates('name').set_index('name')

# %%
len(emote_df)
# Out:
# 1092

# %%
chat_logs = listdir('./Chat Logs/')
chat_logs = ['./Chat Logs/' + file for file in chat_logs]
data = streaming_chat.combine_chat_logs(chat_logs)

# %%
df = pd.DataFrame(data)

# %%
chat_logs = listdir('./Chat Logs/')
streamers = set()
for log in chat_logs:
    streamers.add(log.split('.log')[0])

# %%
df.loc[df.message.apply(len) == 0, 'message'] = np.NaN

df.loc[df['channel'].apply(lambda row: row not in streamers), 'message'] = np.NaN

df.dropna(inplace=True)

# %%
def emote_count2(message):
    emote_freq = defaultdict(int)
    message_data = message.split(' ')
    for word in message_data:
        is_emote = word in emote_df.index
        if is_emote:
            emote_freq[word] += 1
    return Counter(emote_freq)

# %%
df['msg_emotes'] = df.swifter.apply(lambda row: emote_count2(row.message), axis=1)

# %%
count_df = pd.DataFrame(index = emote_count.keys(), data=emote_count.values())
emote_df = pd.merge(left=emote_df, right=count_df, how='left', left_index=True, right_index=True)
emote_df.rename(columns={0: "emote_count"}, inplace=True)

# %%
emote_freq_channel = df.groupby('channel').msg_emotes.sum()
pd.merge(left=emote_df, right=pd.Series(emote_freq_channel['fedmyster']).rename('fedmyster_count'), how='left',left_index=True, right_index=True)

for key in emote_freq_channel.keys():
    emote_df = pd.merge(left=emote_df, right=pd.Series(emote_freq_channel[key]).rename(f'{key}_count'),
                        how='left', left_index=True, right_index=True)

# %%
total_messages = df.groupby('channel').message.count()
total_messages
# Out:
# channel
# fedmyster     41553
# lilypichu     41753
# pokimane      44176
# scarra        43619
# sykkuno       42348
# xchocobars    43475
# yassuo        41413
# yvonnie        8381
# Name: message, dtype: int64

# %%
x = df.groupby(['channel', 'username'])['message'].count().sort_values().groupby(level=0).tail(5)
x['fedmyster'].index.values
# Out:
# array(['spirit56', 'damstream3', 'fk148', 'izagamii', 'faerydaeflo'],
#       dtype=object)

# %%
df['is_@_streamer'] = df.apply(lambda row: row['message'].lower().startswith(f"@{row['channel']}"), axis = 1)

# %%
num_messages = df.loc[df['is_@_streamer'] == True].groupby('channel').message.count().sort_values()

# %%
num_messages
# Out:
# channel
# yvonnie         73
# fedmyster      101
# lilypichu      318
# pokimane       401
# xchocobars     401
# sykkuno        496
# scarra        1070
# yassuo        1817
# Name: message, dtype: int64

# %%
df['question_mark_messages'] = df.apply(lambda row: row['message'].startswith('?'), axis = 1)

# %%
df.loc[df['question_mark_messages'] == True].groupby('channel').message.count().sort_values()
# Out:
# channel
# yvonnie        12
# lilypichu      65
# xchocobars    193
# scarra        209
# sykkuno       258
# yassuo        364
# pokimane      542
# fedmyster     584
# Name: message, dtype: int64

# %%
df['command_message'] = df.apply(lambda row: row['message'].startswith('!'), axis = 1)

# %%
df.loc[df['command_message'] == True].groupby('channel').message.count().sort_values()
# Out:
# channel
# fedmyster       98
# xchocobars     103
# yvonnie        182
# sykkuno        415
# pokimane       723
# lilypichu      918
# scarra         950
# yassuo        1530
# Name: message, dtype: int64

# %%
command_count_per_channel = df.loc[df['command_message'] == True].groupby(['channel','message'])['username'].count()
top_commands_per_channel = command_count_per_channel.sort_values().groupby(level=0).tail(3).sort_index()
top_commands_per_channel
# Out:
# channel     message
# fedmyster   !discord        5
#             !subs           5
#             !uptime        47
# lilypichu   !donate       113
#             !team          61
#             !uptime       260
# pokimane    !followage     90
#             !shaders      164
#             !uptime        81
# scarra      !rank          84
#             !squad        142
#             !uptime       101
# sykkuno     !duo          109
#             !shaders       31
#             !uptime       149
# xchocobars  !song          11
#             !tourney       12
#             !uptime        19
# yassuo      !charity      240
#             !rank         204
#             !uptime       280
# yvonnie     !charity       84
#             !uptime        34
#             !watchtime      9
# Name: username, dtype: int64

# %%
df['message_length'] = df.message.swifter.apply(lambda msg: len(msg.split(' ')))
# Out:
# C:\Users\crsar\Anaconda3\lib\site-packages\tqdm\std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=306718, style=ProgressStyle(description_wi…

# %%
df.groupby('channel')['message_length'].median()
# Out:
# channel
# fedmyster     1
# lilypichu     2
# pokimane      2
# scarra        3
# sykkuno       2
# xchocobars    3
# yassuo        2
# yvonnie       3
# Name: message_length, dtype: int64

# %%
emote_df['xchocobars_count'].sort_values(ascending=False).head(5)
# Out:
# name
# Pog      1501.0
# LUL      1374.0
# LULW      813.0
# YEP       568.0
# PepoG     371.0
# Name: xchocobars_count, dtype: float64

# %%
t1 = pd.merge(emote_df.loc[emote_df.emote_type == 'Tier 1'], emote_channel_df, left_index=True, right_on = 'name')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-168-dc3bf0d4cd4e> in <module>
# ----> 1 pd.merge(emote_df.loc[emote_df.emote_type == 'Tier 3'], emote_channel_df, left_index=True, right_on = 'name')
#
# NameError: name 'emote_df' is not defined

# %%
t1.groupby('channel').sum().drop('emote_count', axis = 1)
# Out:
#             fedmyster_count  lilypichu_count  pokimane_count  scarra_count  \
# channel
# fedmyster           37379.0            593.0           277.0         225.0
# lilypichu             518.0           7568.0           126.0         166.0
# pokimane               83.0            119.0          3235.0          20.0
# scarra                 17.0             67.0            20.0        1351.0
# sykkuno               374.0            401.0            50.0          55.0
# xchocobars              0.0             37.0            13.0           4.0
# yassuo                  7.0              1.0            28.0           6.0
# yvonnie                55.0             66.0            15.0          23.0
#
#             sykkuno_count  xchocobars_count  yassuo_count  yvonnie_count
# channel
# fedmyster           442.0              15.0           2.0           43.0
# lilypichu           140.0              51.0           0.0           11.0
# pokimane              7.0              12.0           4.0            2.0
# scarra                6.0               0.0           0.0            0.0
# sykkuno           10611.0              35.0           2.0           62.0
# xchocobars            0.0            1377.0           1.0            2.0
# yassuo                5.0               0.0        2742.0            0.0
# yvonnie              25.0               8.0           0.0         1652.0

# %%
df['num_emotes'] = df.msg_emotes.swifter.apply(lambda x: sum(x.values()))
# Out:
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=306718, style=ProgressStyle(description_wi…

# %%
df['emote_ratio'] = df['num_emotes'] / df['message_length']

# %%
df
# Out:
#                       time    channel          username  \
# 0      2020-06-04 22:34:00  fedmyster       uplandace12
# 1      2020-06-04 22:34:00  fedmyster           impmeta
# 2      2020-06-04 22:34:00  fedmyster          tiger662
# 3      2020-06-04 22:34:00  fedmyster  thatoneasianboye
# 4      2020-06-04 22:34:01  fedmyster   liberianrefugee
# ...                    ...        ...               ...
# 309104 2020-06-05 00:50:43    yvonnie        tv_timeout
# 309105 2020-06-05 00:50:43    yvonnie        luigi99212
# 309106 2020-06-05 00:50:43    yvonnie          snowtheo
# 309107 2020-06-05 00:50:45    yvonnie            mcboi9
# 309108 2020-06-05 00:50:45    yvonnie    kaiseroverlord
#
#                                                   message    msg_emotes  \
# 0                                                      🥵🥵            {}
# 1       fed7 fed7 fed7 fed7 fed7 fed7 fed7 fed7 fed7 f...  {'fed7': 22}
# 2                      fedL fedL fedL fedL fedL fedL fedL   {'fedL': 7}
# 3                  THE MAN THE MYTH THE LEGENDS IS BACKKK            {}
# 4                                                     ppp            {}
# ...                                                   ...           ...
# 309104         i don't think it's your call at that point            {}
# 309105                       FEEL THE SAME THEY FELT KEKW   {'KEKW': 1}
# 309106                           no she worked hard on it            {}
# 309107                               cmon yvonne content!            {}
# 309108                    Everyone donate a dollar quick!            {}
#
#         is_@_streamer  question_mark_messages  command_message  \
# 0               False                   False            False
# 1               False                   False            False
# 2               False                   False            False
# 3               False                   False            False
# 4               False                   False            False
# ...               ...                     ...              ...
# 309104          False                   False            False
# 309105          False                   False            False
# 309106          False                   False            False
# 309107          False                   False            False
# 309108          False                   False            False
#
#         message_length  num_emotes  emote_ratio
# 0                    1           0     0.000000
# 1                   22          22     1.000000
# 2                    7           7     1.000000
# 3                    8           0     0.000000
# 4                    1           0     0.000000
# ...                ...         ...          ...
# 309104               9           0     0.000000
# 309105               6           1     0.166667
# 309106               6           0     0.000000
# 309107               3           0     0.000000
# 309108               5           0     0.000000
#
# [306718 rows x 11 columns]

# %%
df.groupby('channel')['emote_ratio'].mean()
# Out:
# channel
# fedmyster     0.441596
# lilypichu     0.215585
# pokimane      0.266738
# scarra        0.176698
# sykkuno       0.170896
# xchocobars    0.166829
# yassuo        0.212750
# yvonnie       0.203686
# Name: emote_ratio, dtype: float64

# %%
def filter_words(msg, msg_emotes):
    ret = []
    for word in msg.split(' '):
        if word not in msg_emotes:
            ret.append(word)
    return ' '.join(ret)

# %%
df['message_no_emotes'] = df.swifter.apply(lambda row: filter_words(row['message'], row['msg_emotes']), axis=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=306718, style=ProgressStyle(description_wi…

# %%
df
# Out:
#                       time    channel          username  \
# 0      2020-06-04 22:34:00  fedmyster       uplandace12
# 1      2020-06-04 22:34:00  fedmyster           impmeta
# 2      2020-06-04 22:34:00  fedmyster          tiger662
# 3      2020-06-04 22:34:00  fedmyster  thatoneasianboye
# 4      2020-06-04 22:34:01  fedmyster   liberianrefugee
# ...                    ...        ...               ...
# 309104 2020-06-05 00:50:43    yvonnie        tv_timeout
# 309105 2020-06-05 00:50:43    yvonnie        luigi99212
# 309106 2020-06-05 00:50:43    yvonnie          snowtheo
# 309107 2020-06-05 00:50:45    yvonnie            mcboi9
# 309108 2020-06-05 00:50:45    yvonnie    kaiseroverlord
#
#                                                   message    msg_emotes  \
# 0                                                      🥵🥵            {}
# 1       fed7 fed7 fed7 fed7 fed7 fed7 fed7 fed7 fed7 f...  {'fed7': 22}
# 2                      fedL fedL fedL fedL fedL fedL fedL   {'fedL': 7}
# 3                  THE MAN THE MYTH THE LEGENDS IS BACKKK            {}
# 4                                                     ppp            {}
# ...                                                   ...           ...
# 309104         i don't think it's your call at that point            {}
# 309105                       FEEL THE SAME THEY FELT KEKW   {'KEKW': 1}
# 309106                           no she worked hard on it            {}
# 309107                               cmon yvonne content!            {}
# 309108                    Everyone donate a dollar quick!            {}
#
#         is_@_streamer  question_mark_messages  command_message  \
# 0               False                   False            False
# 1               False                   False            False
# 2               False                   False            False
# 3               False                   False            False
# 4               False                   False            False
# ...               ...                     ...              ...
# 309104          False                   False            False
# 309105          False                   False            False
# 309106          False                   False            False
# 309107          False                   False            False
# 309108          False                   False            False
#
#         message_length  num_emotes  emote_ratio  \
# 0                    1           0     0.000000
# 1                   22          22     1.000000
# 2                    7           7     1.000000
# 3                    8           0     0.000000
# 4                    1           0     0.000000
# ...                ...         ...          ...
# 309104               9           0     0.000000
# 309105               6           1     0.166667
# 309106               6           0     0.000000
# 309107               3           0     0.000000
# 309108               5           0     0.000000
#
#                                  message_no_emotes
# 0                                               🥵🥵
# 1
# 2
# 3           THE MAN THE MYTH THE LEGENDS IS BACKKK
# 4                                              ppp
# ...                                            ...
# 309104  i don't think it's your call at that point
# 309105                     FEEL THE SAME THEY FELT
# 309106                    no she worked hard on it
# 309107                        cmon yvonne content!
# 309108             Everyone donate a dollar quick!
#
# [306718 rows x 12 columns]

# %%
emote_channel_df.to_pickle('emote_channel.pkl')

# %%
emote_df.to_pickle('emote.pkl')

# %%
df = pd.read_msgpack('./Data/chat_data.msg')

# %%
df.to_pickle('chat_data.pkl')

# %%
df = pd.read_pickle('chat_data.pkl')

# %%
emote = pd.read_pickle('./Data/emote.pkl')

# %%
emote_channel_df = pd.read_pickle('./Data/emote_channel.pkl')

# %%
emote['modified_emote_type'] = emote['emote_type']

# %%
emote.loc[emote['modified_emote_type'].apply(lambda x : x.startswith("FrankerFaceZ")), 'modified_emote_type'] = 'FrankerFaceZ'

# %%
emote.loc[emote['modified_emote_type'].apply(lambda x : x.startswith("BetterTTV")), 'modified_emote_type'] = 'BetterTTV'

# %%
xd = pd.merge(emote.loc[(emote.modified_emote_type == 'Tier 1') | (emote.modified_emote_type == 'Tier 2') | (emote.modified_emote_type == 'Tier 3')], emote_channel_df, left_index=True, right_on = 'name')
xd.loc[(xd['modified_emote_type'] == 'Tier 1') & (xd['channel'] == 'fedmyster')].emote_count.sum()
# Out:
# 38976.0

# %%
xd.loc['fedmyster']['fedmyster_count']
# Out:
# emote_type
# Tier 1    37379.0
# Tier 2        0.0
# Tier 3      367.0
# Name: fedmyster_count, dtype: float64

# %%
dx = emote.groupby('modified_emote_type').sum()
dx = dx.drop('emote_count', axis=1).transpose()

# %%
dx
# Out:
# modified_emote_type  BetterTTV  FrankerFaceZ  Global Twitch   Tier 1  Tier 2  \
# fedmyster_count        11263.0       14796.0         5722.0  38433.0     0.0
# lilypichu_count         2445.0        4047.0         7260.0   8852.0     5.0
# pokimane_count          6638.0        6455.0        12604.0   3764.0     0.0
# scarra_count            2568.0        7653.0         2876.0   1850.0     0.0
# sykkuno_count           1145.0        3694.0         3997.0  11236.0     0.0
# xchocobars_count        2234.0        5074.0         2671.0   1498.0     7.0
# yassuo_count            4207.0        7670.0         5035.0   2751.0     0.0
# yvonnie_count            249.0         930.0          876.0   1772.0     0.0
#
# modified_emote_type  Tier 3
# fedmyster_count       367.0
# lilypichu_count         0.0
# pokimane_count         23.0
# scarra_count            2.0
# sykkuno_count           0.0
# xchocobars_count        2.0
# yassuo_count            0.0
# yvonnie_count           0.0

# %%
# 14796(FrankerFaceZ) + 11263(BetterTTV) + 367 + 38433 + 5722(Global Twitch)
# Out:
# 70581

# %%
series = []
channels = df.channel.unique()
for c in channels:
    print((xd[f'{c}_count']).sum() - (xd.loc[c][f'{c}_count']).sum())
#     multi_index = pd.MultiIndex.from_tuples(list(zip(top_ind, emotes.index)))
#     series.append(pd.Series(emotes.values, index=multi_index))
# Out:
# 1054.0
# 1284.0
# 529.0
# 499.0
# 625.0
# 121.0
# 9.0
# 120.0

# %%
grumps = pd.merge(emote, emote_channel_df, left_index=True, right_on='name').drop_duplicates('name').groupby(['channel', 'modified_emote_type']).sum()

# %%
def combine_series(v1, v2):
    if v1 and v2:
        return v1 + v2
    elif v1:
        return v1
    else:
        return v2

# %%
grumps['fedmyster_count']['fedmyster'].combine(grumps['fedmyster_count']['global'], lambda )
# Out:
# modified_emote_type
# BetterTTV         9897.0
# FrankerFaceZ     14774.0
# Global Twitch     5722.0
# Tier 1           37379.0
# Tier 2               0.0
# Tier 3             367.0
# Name: fedmyster_count, dtype: float64

# %%
grumps
# Out:
#                                 emote_count  fedmyster_count  lilypichu_count  \
# channel    modified_emote_type
# fedmyster  BetterTTV                20035.0           9897.0            937.0
#            FrankerFaceZ             48395.0          14774.0           3900.0
#            Tier 1                   38976.0          37379.0            593.0
#            Tier 2                       0.0              0.0              0.0
#            Tier 3                     367.0            367.0              0.0
# global     BetterTTV                 4390.0           1312.0            419.0
#            FrankerFaceZ                10.0              0.0              0.0
#            Global Twitch            41041.0           5722.0           7260.0
# lilypichu  BetterTTV                 1823.0              2.0           1074.0
#            FrankerFaceZ               333.0              3.0            138.0
#            Tier 1                    8580.0            518.0           7568.0
#            Tier 2                       5.0              0.0              5.0
#            Tier 3                       0.0              0.0              0.0
# pokimane   BetterTTV                 2080.0             43.0              6.0
#            FrankerFaceZ              1104.0             13.0              4.0
#            Tier 1                    3482.0             83.0            119.0
#            Tier 2                       0.0              0.0              0.0
#            Tier 3                      23.0              0.0              0.0
# scarra     BetterTTV                  100.0              0.0              0.0
#            FrankerFaceZ                 5.0              0.0              0.0
#            Tier 1                    1461.0             17.0             67.0
#            Tier 2                       0.0              0.0              0.0
#            Tier 3                       2.0              0.0              0.0
# sykkuno    BetterTTV                    1.0              0.0              0.0
#            FrankerFaceZ                22.0              0.0              0.0
#            Tier 1                   11590.0            374.0            401.0
# xchocobars BetterTTV                  244.0              4.0              0.0
#            FrankerFaceZ                60.0              0.0              0.0
#            Tier 1                    1434.0              0.0             37.0
#            Tier 2                       7.0              0.0              0.0
#            Tier 3                       2.0              0.0              0.0
# yassuo     BetterTTV                 2061.0              5.0              9.0
#            FrankerFaceZ               365.0              2.0              3.0
#            Tier 1                    2789.0              7.0              1.0
# yvonnie    BetterTTV                   15.0              0.0              0.0
#            FrankerFaceZ                25.0              4.0              2.0
#            Tier 1                    1844.0             55.0             66.0
#            Tier 2                       0.0              0.0              0.0
#            Tier 3                       0.0              0.0              0.0
#
#                                 pokimane_count  scarra_count  sykkuno_count  \
# channel    modified_emote_type
# fedmyster  BetterTTV                    3438.0        1772.0          752.0
#            FrankerFaceZ                 5447.0        7605.0         3645.0
#            Tier 1                        277.0         225.0          442.0
#            Tier 2                          0.0           0.0            0.0
#            Tier 3                          0.0           0.0            0.0
# global     BetterTTV                     913.0         633.0          339.0
#            FrankerFaceZ                    2.0           7.0            1.0
#            Global Twitch               12604.0        2876.0         3997.0
# lilypichu  BetterTTV                     499.0          27.0           34.0
#            FrankerFaceZ                  101.0          12.0           21.0
#            Tier 1                        126.0         166.0          140.0
#            Tier 2                          0.0           0.0            0.0
#            Tier 3                          0.0           0.0            0.0
# pokimane   BetterTTV                    1754.0          32.0           15.0
#            FrankerFaceZ                  886.0          15.0            5.0
#            Tier 1                       3235.0          20.0            7.0
#            Tier 2                          0.0           0.0            0.0
#            Tier 3                         23.0           0.0            0.0
# scarra     BetterTTV                      21.0          73.0            0.0
#            FrankerFaceZ                    0.0           5.0            0.0
#            Tier 1                         20.0        1351.0            6.0
#            Tier 2                          0.0           0.0            0.0
#            Tier 3                          0.0           2.0            0.0
# sykkuno    BetterTTV                       0.0           0.0            1.0
#            FrankerFaceZ                    0.0           0.0           21.0
#            Tier 1                         50.0          55.0        10611.0
# xchocobars BetterTTV                       3.0           2.0            0.0
#            FrankerFaceZ                    3.0           0.0            0.0
#            Tier 1                         13.0           4.0            0.0
#            Tier 2                          0.0           0.0            0.0
#            Tier 3                          0.0           0.0            0.0
# yassuo     BetterTTV                      10.0          29.0            4.0
#            FrankerFaceZ                   14.0           4.0            1.0
#            Tier 1                         28.0           6.0            5.0
# yvonnie    BetterTTV                       0.0           0.0            0.0
#            FrankerFaceZ                    2.0           5.0            0.0
#            Tier 1                         15.0          23.0           25.0
#            Tier 2                          0.0           0.0            0.0
#            Tier 3                          0.0           0.0            0.0
#
#                                 xchocobars_count  yassuo_count  yvonnie_count
# channel    modified_emote_type
# fedmyster  BetterTTV                      1382.0        1715.0          142.0
#            FrankerFaceZ                   4943.0        7160.0          921.0
#            Tier 1                           15.0           2.0           43.0
#            Tier 2                            0.0           0.0            0.0
#            Tier 3                            0.0           0.0            0.0
# global     BetterTTV                       429.0         258.0           87.0
#            FrankerFaceZ                      0.0           0.0            0.0
#            Global Twitch                  2671.0        5035.0          876.0
# lilypichu  BetterTTV                       135.0          48.0            4.0
#            FrankerFaceZ                     54.0           2.0            2.0
#            Tier 1                           51.0           0.0           11.0
#            Tier 2                            0.0           0.0            0.0
#            Tier 3                            0.0           0.0            0.0
# pokimane   BetterTTV                        83.0         147.0            0.0
#            FrankerFaceZ                      6.0         175.0            0.0
#            Tier 1                           12.0           4.0            2.0
#            Tier 2                            0.0           0.0            0.0
#            Tier 3                            0.0           0.0            0.0
# scarra     BetterTTV                         5.0           0.0            1.0
#            FrankerFaceZ                      0.0           0.0            0.0
#            Tier 1                            0.0           0.0            0.0
#            Tier 2                            0.0           0.0            0.0
#            Tier 3                            0.0           0.0            0.0
# sykkuno    BetterTTV                         0.0           0.0            0.0
#            FrankerFaceZ                      0.0           0.0            1.0
#            Tier 1                           35.0           2.0           62.0
# xchocobars BetterTTV                       200.0          35.0            0.0
#            FrankerFaceZ                     57.0           0.0            0.0
#            Tier 1                         1377.0           1.0            2.0
#            Tier 2                            7.0           0.0            0.0
#            Tier 3                            2.0           0.0            0.0
# yassuo     BetterTTV                         0.0        2004.0            0.0
#            FrankerFaceZ                     13.0         328.0            0.0
#            Tier 1                            0.0        2742.0            0.0
# yvonnie    BetterTTV                         0.0           0.0           15.0
#            FrankerFaceZ                      1.0           5.0            6.0
#            Tier 1                            8.0           0.0         1652.0
#            Tier 2                            0.0           0.0            0.0
#            Tier 3                            0.0           0.0            0.0
